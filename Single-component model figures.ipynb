# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(16,5))

x = np.arange(-70,60,0.1)

plt.subplot(1,2,1)
plt.plot(x, (1/(1+np.exp((-24-x)/10.5)))**4, label = 'Chosen model', lw=6)
plt.plot(x, 1/(1+np.exp((-9.2-x)/6.6)), label = 'VanDongen et al. 1990')
plt.plot(x, 1/(1+np.exp((11.4-x)/12.1)), label = 'Shi et al. 1994')
plt.plot(x, 1/(1+np.exp((1-x)/11)), label = 'Kerschensteiner et al. 1999')
plt.plot(x, (1/(1+np.exp((-33.2-x)/9.1)))**4, label = u'Günay et al. 2008', color='purple')
plt.legend()
plt.xlabel('Voltage (mV)')
plt.title('Kv2.1 activation')

plt.subplot(1,2,2)

plt.plot(x, .2+.8/(1+np.exp((-26-x)/-6)), label='Chosen model', lw=6)
plt.plot(x, .25+.75/(1+np.exp((-19-x)/-5)), label='VanDongen et al. 1990')
plt.plot(x, .18+.82/(1+np.exp((-25.2-x)/-5.8)), label='Shi et al. 1994')
plt.plot(x, .2+.8/(1+np.exp((-34.7-x)/-4.4)), label='Kerschensteiner et al. 1999')
plt.plot(x, .2+.8/(1+np.exp((-20-x)/-10)), label=u'Günay et al. 2008', color='purple')
plt.plot(x, .2+.8/(1+np.exp((-26-x)/-6.7)), label='Klemic et al. 1998', color='cyan')
plt.plot(x, 1/(1+np.exp((-11.4-x)/-8.5)), label='Li et al. 2015', color='magenta')
plt.legend()
plt.xlabel('Voltage (mV)')
plt.title('Kv2.1 inactivation')

plt.savefig('/home/kernfel/Documents/Thesis/Experiments figures/Kv21_nh.svg', bbox_inches='tight')

# %%
tau4_Kerschensteiner = [6.43,7.2,7.91,9.22,10.66,13.18,18.77,28.64,36.51,88,59,40,29,19.5]
tau4_Kerschensteiner_V = np.arange(60,-71,-10)

plt.figure(figsize=(16,5))

plt.subplot(1,2,1)
x = np.arange(-70,60,0.1)
plt.plot(x, 5 + 110/(np.exp((x+36)/18)+np.exp((x+36)/-17)), label='Chosen model', lw=6)
plt.plot(tau4_Kerschensteiner_V, tau4_Kerschensteiner, 'r*', label='Kerschensteiner et al. 1999')
plt.plot(x, 0.1+29.9/(np.exp((-33.2-x)/21.7)+np.exp((-33.2-x)/-13.9)), color='purple', label=u'Günay et al. 2008')
plt.plot([-10, 40], [8.2, 2.5], '*', color='magenta', label='Li et al. 2015')
plt.title('Kv2.1 activation tau')
plt.legend()
plt.ylabel('ms')
plt.xlabel('Voltage (mV)')

taui_Klemic = [270.551126441926,499.170537705386,1573.97630534975,9393.56295904351,22948.0839868864,5222.92836440641,4716.07608459138,4151.10979174849,4313.09669775924,4656.28060527803,5156.70646735319,5567.0146054279,5933.76922958617,6324.68562874863,6655.88143075347,7004.42049149149,7277.75086836331]
taui_Klemic_V = [-139.901362619483,-119.852552369331,-89.7610331502949,-60.0732153752288,-40.4565792149685,-20.1199918649584,-10.1281269066504,-0.138295708765554,9.86475493186902,19.8708562131382,29.8789912548302,39.8850925360993,49.4356314826114,59.8952613382144,69.8993288590602,79.9033963799066,89.9064470205408]

ax=plt.subplot(1,2,2)
x = np.arange(-150,100,0.1)
plt.plot(x, 400+3000/(1+np.exp((x+80)/-15)), label='Chosen model', lw=6)
plt.plot([-130,-80], [131, 1308], 'r*', label='Kerschensteiner et al. 1999')
plt.plot(x, [3400]*len(x), color='purple', label=u'Günay et al. 2008')
plt.plot(taui_Klemic_V, taui_Klemic, '*', color='cyan', label='Klemic et al. 1998')
ax.set_yscale('log')
plt.title('Kv2.1 inactivation tau')
plt.legend()
plt.ylabel('ms')
plt.xlabel('Voltage (mV)')

plt.savefig('/home/kernfel/Documents/Thesis/Experiments figures/Kv21_tau.svg', bbox_inches='tight')

# %%
plt.figure(figsize=(16,5))

x = np.arange(-100,60,0.1)

plt.subplot(1,2,1)
plt.plot(x, (1/(1+np.exp((-55-x)/20)))**4, label='Chosen model', lw=6)
plt.plot(x, 1/(1+np.exp((-30-x)/16.9)), label=u'Stühmer et al. 1989')
plt.plot(x, 1/(1+np.exp((-9.9-x)/15.5)), label='Nunoki et al. 1994')
plt.plot(x, (1/(1+np.exp((-47.5-x)/10.5)))**4, label='McIntosh et al. 1997')
plt.plot(x, 1/(1+np.exp((-12.2-x)/13.9)), label='Hashimoto et al. 2000')
plt.plot(x, 1/(1+np.exp((-17.6-x)/17.5)), label='Hagiwara, et al. 2004')
plt.legend()
plt.xlabel('Voltage (mV)')
plt.title('Kv1.4 activation')

plt.subplot(1,2,2)
plt.plot(x, .05+.95/(1+np.exp((-x-48)/-5)), label='Chosen model', lw=6)
plt.plot(x, 1/(1+np.exp((-x-73.6)/-12.8)), label=u'Stühmer et al. 1989')
plt.plot(x, .06+.94/(1+np.exp((-x-43.5)/-4.7)), label='Nunoki et al. 1994')
plt.plot(x, 1/(1+np.exp((-x-63.1)/-4.1)), label='McIntosh et al. 1997')
plt.plot(x, .09+.91/(1+np.exp((-x-44.2)/-6.1)), label='Hagiwara, et al. 2004')
plt.plot(x, 0.03+.97/(1+np.exp((-x-36.2)/-5.9)), label='Hashimoto et al. 2000')
plt.plot(x, 1/(1+np.exp((-x-54)/-3.3)), label='Rettig et al. 1994')
plt.legend()
plt.xlabel('Voltage (mV)')
plt.title('Kv1.4 inactivation')

plt.savefig('/home/kernfel/Documents/Thesis/Experiments figures/Kv14_nh.svg', bbox_inches='tight')

# %%
tau4_mcintosh = [17.5,22.5,28.5,35.5,43.4,56.5,72,69,32,15,7]
tau4_mcintosh_V = np.arange(-120,-19,10)
x = np.arange(-120,60,0.1)

plt.figure(figsize=(16,5))

plt.subplot(1,2,1)
plt.plot(x, 2+102/(np.exp((45+x)/6)+np.exp((45+x)/-40)), label='Chosen model', lw=6)
plt.plot(tau4_mcintosh_V, tau4_mcintosh, 'r*', label='McIntosh et al. 1997')
plt.title('Kv1.4 activation tau')
plt.legend()
plt.ylabel('ms')
plt.xlabel('Voltage (mV)')

taui_mcintosh = [60.67,59.28,53.92,46.47,41.82,38.57,39.98,37.19,38.37,38.85,39.91,41.08,42.26,43.21,44.15,44.98,45.81]
taui_mcintosh_V = np.arange(-60,101,10)

ax=plt.subplot(1,2,2)
plt.plot(x, 35+10e3/(1+np.exp((72+x)/7)), label='Chosen model', lw=6)

plt.plot(0, 109, '*', label=u'Stühmer et al. 1989')
plt.plot([20, -80], [71, 8.1e3], '*', label='Nunoki et al. 1994')
plt.plot(taui_mcintosh_V, taui_mcintosh, '*', label='McIntosh et al. 1997')
plt.plot(20, 51, '*', label='Hagiwara, et al. 2004')
plt.plot([20, -80], [65, 9.4e3], '*', label='Hashimoto et al. 2000')
plt.plot(50, 26, '*', label='Rettig et al. 1994')
# plt.plot([-40,-30,0,20,40], [131,54,44,36,34], '*', label='Comer et al. 1994')
ax.set_yscale('log')
plt.title('Kv1.4 inactivation tau')
plt.legend()
plt.ylabel('ms')
plt.xlabel('Voltage (mV)')

plt.savefig('/home/kernfel/Documents/Thesis/Experiments figures/Kv14_tau.svg', bbox_inches='tight')
